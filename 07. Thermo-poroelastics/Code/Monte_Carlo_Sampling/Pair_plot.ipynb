# %%
import os

path = os.getcwd()

os.chdir(r'C:\Users\yul184\Dropbox\P&A Project\15. Publications\07. Thermo-poroelastics\Code\Monte_Carlo_Sampling') 

path = os.getcwd()

print(path)
# Out:
# C:\Users\yul184\Dropbox\P&A Project\15. Publications\07. Thermo-poroelastics\Code\Monte_Carlo_Sampling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import *
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, BaggingRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import confusion_matrix, classification_report, mean_squared_error
pd.set_option('display.notebook_repr_html', False)
# %matplotlib inline
plt.style.use('seaborn-white')
from sys import getsizeof
from matplotlib import colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import scipy as sp
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sklearn.linear_model as sklm
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score, roc_curve, roc_auc_score
from sklearn import preprocessing
from sklearn import neighbors
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})
import matplotlib.pylab as plt
from matplotlib import pyplot as plt  
import csv
import math
import matplotlib.pylab as plt
import pdb

# %%
import pandas as pd
voice = pd.read_csv('Total.csv');

# %%
voice.info()
list(voice.columns.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1642 entries, 0 to 1641
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Biot                          1642 non-null   float64
#  1   Thermal Expansion of Solid    1642 non-null   float64
#  2   Thermal Expansion Difference  1642 non-null   float64
#  3   Bulk Modulus                  1642 non-null   float64
#  4   Skempton                      1642 non-null   float64
#  5   Shear Modulus                 1642 non-null   float64
#  6   Poisson Ratio                 1642 non-null   float64
#  7   Thermal Filtration            1642 non-null   float64
#  8   Thermal Osmosis               1642 non-null   float64
#  9   Thermal Conductivity          1642 non-null   float64
#  10  Permeability                  1642 non-null   float64
#  11  Specific Heat                 1642 non-null   float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)



sns.heatmap(voice.iloc[:,:-7].astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
plt.tick_params(axis='x', which='major', labelsize=10, labelbottom = False, bottom=False, top = False, labeltop=True)
plt.xticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0.5, 1, 'Biot'),
#   Text(1.5, 1, 'Thermal Expansion of Solid'),
#   Text(2.5, 1, 'Thermal Expansion Difference'),
#   Text(3.5, 1, 'Bulk Modulus'),
#   Text(4.5, 1, 'Skempton'),
#   Text(5.5, 1, 'Shear Modulus'),
#   Text(6.5, 1, 'Poisson Ratio'),
#   Text(7.5, 1, 'Thermal Filtration'),
#   Text(8.5, 1, 'Thermal Osmosis'),
#   Text(9.5, 1, 'Thermal Conductivity'),
#   Text(10.5, 1, 'Permeability'),
#   Text(11.5, 1, 'Specific Heat')])

# %%
g = sns.pairplot(voice[['Biot', 'Thermal Expansion Difference', 'Shear Modulus', 'Bulk Modulus', 'Skempton','Poisson Ratio','Thermal Filtration','Thermal Osmosis','Thermal Conductivity','Permeability','Specific Heat','Case']], 
                size=2,diag_kind="kde",hue="Case")
#g.set_xlabel(fontsize = 10)
#g.set_ylabel(fontsize = 10)
#val =7

#sns.set(font_scale=val)
#plt.xlabel(fontzie=2)
#plt.ylabel(fontzie=2)


for i in range(11):
    g.axes[i,0].set_xlim((0.3,1.2))

for i in range(11):
    g.axes[i,2].set_xlim((1e10,3e10))
    
for i in range(11):
    g.axes[i,3].set_xlim((4e9,2e10))
    
for i in range(11):
    g.axes[i,4].set_xlim((0.3,1.2))
    
for i in range(11):
    g.axes[i,5].set_xlim((0.1,0.35))
    
    
for i in range(11):
    g.axes[0,i].set_ylim((0.4,1.2))

    
for i in range(11):
    g.axes[2,i].set_ylim((0.5e10,2e10))
    
for i in range(11):
    g.axes[3,i].set_ylim((0.5e10,2e10))
    
for i in range(11):
    g.axes[4,i].set_ylim((0.5,1.2))   
       
for i in range(11):
    g.axes[5,i].set_ylim((0.1,0.5))
# Out:
# C:\Users\yul184\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
